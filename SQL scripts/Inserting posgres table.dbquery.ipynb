-- %%
INSERT INTO public."Customers"(
    id, name, email, city, created_on, modified_on, deletedflag)
VALUES
    (1, 'John Doe', 'john.doe@company.com', 'London', now(), now(), false),
    (2, 'Jane Smith', 'jane.smith@company.com', 'Paris', now(), now(), false),
    (3, 'Alice Lee', 'alice.lee@company.com', 'Berlin', now(), now(), false);
